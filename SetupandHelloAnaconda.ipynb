# %% [markdown]
# # Notes for the First Environment Set-Up

# %% [markdown]
# For this first notebook, I will outline the commands I run to set up a new conda environment on my local machine

# %% [markdown]
# ## Installing and Configuring the Conda Environment

# %% [markdown]
# ### Step 1: Create a new conda environment

# %% [markdown]
# Open Terminal.
# run command: conda create --name simple_env

# %% [markdown]
# ### Step 2: Verify the new conda environment has been successfully created

# %% [raw]
# run command: conda env list
# -what is returned is a list of environments, including the base* conda environment

# %% [markdown]
# ### Step 3: Update the Environment with Tools

# %% [raw]
# run command: conda install jupyterlab pandas notebook
# -here we are installing Jupyter Lab, Pandas, and Jupyter Notebook in the 'simple_env' environment

# %% [markdown]
# ### Step 4: Verify Tool Installation

# %% [raw]
# run command: conda list
# -here we are asking conda to return the list of installed packages in our environment

# %% [markdown]
# ### Step 5: Open Tool (Jupyter Lab and Notebook)

# %% [raw]
# run command: jupyter lab
# -jupyter lab opens (validated from image below) on localhost

# %% [markdown]
# ![Screenshot 2024-02-18 at 7.40.56 PM.png](attachment:b093019b-0f40-4a23-a375-4d607a5cfbbf.png)

# %% [raw]
# Running the command 'notebook' in the terminal opened this .ipynb file for documentation.

# %%
print("Hello Anaconda")
# Out:
# Hello Anaconda
